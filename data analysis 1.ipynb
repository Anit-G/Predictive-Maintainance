# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import random
from Helper import prepare_train_data

data_link = './Data/'
train_link = 'train_FD001.txt'
test_link = 'test_FD001.txt'
rul_link = "RUL_FD001.txt"

random.seed(49)
np.random.seed(49)

# %% [markdown]
# # Data Import

# %%
df = pd.read_csv(data_link+train_link,sep=" ",header=None)
df.dropna(axis=1,inplace=True)
columns = ['unit_number','time_in_cycles','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor10','sensor11',
'sensor12','sensor13','sensor14','sensor15','sensor16','sensor17','sensor18','sensor19','sensor20','sensor21','sensor22','sensor23','sensor24', ]
df.columns = columns
pd.options.display.max_columns = 100

# Add RUL
df = prepare_train_data(df)
df.head()
# Out:
#    unit_number  time_in_cycles  sensor1  sensor2  sensor3  sensor4  sensor5  \
# 0            1               1  -0.0007  -0.0004    100.0   518.67   641.82
# 1            1               2   0.0019  -0.0003    100.0   518.67   642.15
# 2            1               3  -0.0043   0.0003    100.0   518.67   642.35
# 3            1               4   0.0007   0.0000    100.0   518.67   642.35
# 4            1               5  -0.0019  -0.0002    100.0   518.67   642.37
#
#    sensor6  sensor7  sensor8  sensor9  sensor10  sensor11  sensor12  sensor13  \
# 0  1589.70  1400.60    14.62    21.61    554.36   2388.06   9046.19       1.3
# 1  1591.82  1403.14    14.62    21.61    553.75   2388.04   9044.07       1.3
# 2  1587.99  1404.20    14.62    21.61    554.26   2388.08   9052.94       1.3
# 3  1582.79  1401.87    14.62    21.61    554.45   2388.11   9049.48       1.3
# 4  1582.85  1406.22    14.62    21.61    554.00   2388.06   9055.15       1.3
#
#    sensor14  sensor15  sensor16  sensor17  sensor18  sensor19  sensor20  \
# 0     47.47    521.66   2388.02   8138.62    8.4195      0.03       392
# 1     47.49    522.28   2388.07   8131.49    8.4318      0.03       392
# 2     47.27    522.42   2388.03   8133.23    8.4178      0.03       390
# 3     47.13    522.86   2388.08   8133.83    8.3682      0.03       392
# 4     47.28    522.19   2388.04   8133.80    8.4294      0.03       393
#
#    sensor21  sensor22  sensor23  sensor24  RUL
# 0      2388     100.0     39.06   23.4190  191
# 1      2388     100.0     39.00   23.4236  190
# 2      2388     100.0     38.95   23.3442  189
# 3      2388     100.0     38.88   23.3739  188
# 4      2388     100.0     38.90   23.4044  187

# %% [markdown]
# # Data Discriptions

# %%
pd.options.display.max_columns = 100
des = df.describe()
des.loc['median'] = df.median().values
des.loc['coeffvariation'] = (df.std()/df.mean()).values
des.loc['nunique'] = df.nunique().values
des.loc['NullCount'] = df.isna().sum().values
des
# Out:
#                  unit_number  time_in_cycles       sensor1       sensor2  \
# count           20631.000000    20631.000000  20631.000000  20631.000000
# mean               51.506568      108.807862     -0.000009      0.000002
# std                29.227633       68.880990      0.002187      0.000293
# min                 1.000000        1.000000     -0.008700     -0.000600
# 25%                26.000000       52.000000     -0.001500     -0.000200
# 50%                52.000000      104.000000      0.000000      0.000000
# 75%                77.000000      156.000000      0.001500      0.000300
# max               100.000000      362.000000      0.008700      0.000600
# median             52.000000      104.000000     -0.000000      0.000000
# coeffvariation      0.567454        0.633052   -246.592698    124.663190
# count           2.063100e+04  20631.000000   20631.0   20631.0  20631.000000
# mean            3.000000e-02    393.210654    2388.0     100.0     38.816271
# std             1.556432e-14      1.548763       0.0       0.0      0.180746
# min             3.000000e-02    388.000000    2388.0     100.0     38.140000
# 25%             3.000000e-02    392.000000    2388.0     100.0     38.700000
# 50%             3.000000e-02    393.000000    2388.0     100.0     38.830000
# 75%             3.000000e-02    394.000000    2388.0     100.0     38.950000
# max             3.000000e-02    400.000000    2388.0     100.0     39.430000
# median          3.000000e-02    393.000000    2388.0     100.0     38.830000
# coeffvariation  5.188105e-13      0.003939       0.0       0.0      0.004656
# nunique         1.000000e+00     13.000000       1.0       1.0    120.000000
# NullCount       0.000000e+00      0.000000       0.0       0.0      0.000000
#
#                     sensor24           RUL
# count           20631.000000  20631.000000
# mean               23.289705    107.807862
# std                 0.108251     68.880990
# min                22.894200      0.000000
# 25%                23.221800     51.000000
# 50%                23.297900    103.000000
# 75%                23.366800    155.000000
# max                23.618400    361.000000
# median             23.297900    103.000000
# coeffvariation      0.004648      0.638924
# nunique          4745.000000    362.000000
# NullCount           0.000000      0.000000

# %%
# find if time_in_cycles is continous
for i in range(1,101):
    tic = df[df['unit_number']==i]['time_in_cycles'].values
    for a,b in zip(tic, np.arange(1,len(tic)+1)):
        if a!=b:
            print(f"TIC is discontinous")
        else:
            pass
print(f'Total analmolies in sensor9: {sum(df.sensor9<21.55)}')

# anamolies present in sensor11 and 16
print(df[df.sensor11<2387.75].unit_number.value_counts())
# Out:
# Total analmolies in sensor9: 0
# Series([], Name: unit_number, dtype: int64)

# %% [markdown]
# # Data plots

# %%
# for col in df.columns:
#   plot_data = df[df['unit_number']==1][col]
#   length = len(plot_data)
#   fig, ax = plt.subplots(1,4,figsize=(30,10),gridspec_kw={'width_ratios': [4,4,4,0.5]})
#   ax[0].plot(np.arange(length),plot_data,marker='.',alpha=0.4)
#   ax[1].scatter(np.arange(len(df[col])),df[col],marker='.',alpha=0.4)
#   sb.histplot(df[col],kde=True,ax=ax[2],)
#   #sb.histplot(df[col],ax=ax[3])
#   sb.boxplot(y=df[col],color='green',orient='v',ax=ax[3])
#   ax[0].set_ylabel(col)
#   ax[1].set_ylabel(col)
#   ax[2].set_xlabel(col)
#   ax[3].set_xlabel(col)
#   plt.show()

# %%
# display the duplicates
fig,ax = plt.subplots(1,3,figsize=(15,5))
sb.histplot(df['sensor10'],ax = ax[0],label='10')
sb.histplot(df['sensor15'].values+32,ax = ax[0],color='r',label='15')

sb.histplot(df['sensor11'],ax = ax[1],label='11')
sb.histplot(df['sensor16'],ax = ax[1],color='r',label='16')

sb.histplot(df['sensor12'],ax = ax[2],label='12')
sb.histplot(df['sensor17'].values+920,ax = ax[2],color='r',label='17')
plt.legend()

# %%
from sklearn.preprocessing import RobustScaler, MinMaxScaler
rb = RobustScaler()
mm = MinMaxScaler()
d = rb.fit_transform(df)
#d = np.sqrt(d)
d = mm.fit_transform(d)
fig, ax = plt.subplots(1,2,figsize=(10,5))
sb.histplot(d[:,10], ax=ax[0])
sb.histplot(df['sensor10'],ax = ax[1])
plt.show()

# %% [markdown]
# # Display random unit_numbers

# %%
# # Correalation Heatmap
# sb.heatmap(df.corr(),annot=True,cmap='RdYlGn',linewidths=0.2,)
# fig = plt.gcf()
# fig.set_size_inches(25,25)
# plt.show()

# %%
# # Display random unit numbers
# a = [55,24,71,11]
# for col in df.columns:
#   fig, ax = plt.subplots(1,4,figsize=(30,10),gridspec_kw={'width_ratios': [1,1,1,1]})
#   for ID,un in zip(ax.ravel(),a):
#     plot_data = df[df['unit_number']==un][col]
#     length = len(plot_data)
#     ID.plot(np.arange(length),plot_data,marker='.',alpha=0.4)
#     ID.set_ylabel(col)
#     ID.set_title(un)
#   plt.show()

# %% [markdown]
# # RUL relations

# %%
# for col in df.columns:
#   plt.scatter(df['RUL'],df[col],marker='.')
#   plt.ylabel(col)
#   plt.xlabel('RUL')
#   plt.show()

# %% [markdown]
# # Scaling and trimming

# %%
# capping sensor20 between 397 and 389
df['sensor20'].clip(lower=389,upper=397,inplace=True)
# Add 24 hour check (180) and 100 hour check (250) and week check (350 cycles)
df['Acheck'] = (df['time_in_cycles']>180).values.astype(int)
df['Bcheck'] = (df['time_in_cycles']>250).values.astype(int)
df['Ccheck'] = (df['time_in_cycles']>300).values.astype(int)

# Dropping useless columns
for a in ['sensor3','sensor4','sensor8','sensor13','sensor19','sensor21','sensor22']:
    df.drop(a,axis=1,inplace=True)

#drop duplicatives sensor 16,17 maybe drop sensor15
for a in ['sensor16','sensor17']:
    df.drop(a,axis=1,inplace=True)

df.head()
# Out:
#    unit_number  time_in_cycles  sensor1  sensor2  sensor5  sensor6  sensor7  \
# 0            1               1  -0.0007  -0.0004   641.82  1589.70  1400.60
# 1            1               2   0.0019  -0.0003   642.15  1591.82  1403.14
# 2            1               3  -0.0043   0.0003   642.35  1587.99  1404.20
# 3            1               4   0.0007   0.0000   642.35  1582.79  1401.87
# 4            1               5  -0.0019  -0.0002   642.37  1582.85  1406.22
#
#    sensor9  sensor10  sensor11  sensor12  sensor14  sensor15  sensor18  \
# 0    21.61    554.36   2388.06   9046.19     47.47    521.66    8.4195
# 1    21.61    553.75   2388.04   9044.07     47.49    522.28    8.4318
# 2    21.61    554.26   2388.08   9052.94     47.27    522.42    8.4178
# 3    21.61    554.45   2388.11   9049.48     47.13    522.86    8.3682
# 4    21.61    554.00   2388.06   9055.15     47.28    522.19    8.4294
#
#    sensor20  sensor23  sensor24  RUL  Acheck  Bcheck  Ccheck
# 0       392     39.06   23.4190  191       0       0       0
# 1       392     39.00   23.4236  190       0       0       0
# 2       390     38.95   23.3442  189       0       0       0
# 3       392     38.88   23.3739  188       0       0       0
# 4       393     38.90   23.4044  187       0       0       0

# %%
#scaling
from scaling import scaling
from describe import describe
cols_normalize = df.columns.difference(['unit_number','time_in_cycles','RUL'])
df_t = scaling(df,cols_normalize,scalers='Robust_Scaler',single=True)
df_t = scaling(df_t,cols_normalize,scalers='MinMax',single=True)
# print(df.columns.difference(cols_normalize))
# df = df[df.columns.difference(cols_normalize)].join(df_t)

#sqrt sensor 10-12 from df_t
#df_t = df_t[df_t.columns.difference(['sensor10','sensor11','sensor12'])].join(df_t[['sensor10','sensor11','sensor12']].apply(np.sqrt))

#add 'unit_number','time_in_cycles','RUL' to df_t
df = df_t.join(df[['unit_number','time_in_cycles','RUL']])

# describe function
des = describe(df)
#drop unit_number
unit_number = pd.DataFrame(df["unit_number"])
df = df.drop(columns='unit_number',axis=1)

# for col in df.columns:
#   plot_data = df[df['unit_number']==1][col]
#   length = len(plot_data)
#   fig, ax = plt.subplots(1,4,figsize=(30,10),gridspec_kw={'width_ratios': [4,4,4,0.5]})
#   ax[0].plot(np.arange(length),plot_data,marker='.',alpha=0.4)
#   ax[1].scatter(np.arange(len(df[col])),df[col],marker='.',alpha=0.4)
#   sb.histplot(df[col],kde=True,ax=ax[2],)
#   #sb.histplot(df[col],ax=ax[3])
#   sb.boxplot(y=df[col],color='green',orient='v',ax=ax[3])
#   ax[0].set_ylabel(col)
#   ax[1].set_ylabel(col)
#   ax[2].set_xlabel(col)
#   ax[3].set_xlabel(col)
#   plt.show()
des
# Out:
# single: True
# Columns: Index(['Acheck', 'Bcheck', 'Ccheck', 'sensor1', 'sensor10', 'sensor11',
#        'sensor12', 'sensor14', 'sensor15', 'sensor18', 'sensor2', 'sensor20',
#        'sensor23', 'sensor24', 'sensor5', 'sensor6', 'sensor7', 'sensor9'],
#       dtype='object')
# Transformer: <class 'sklearn.preprocessing._data.RobustScaler'>
#
# single: True
# Columns: Index(['Acheck', 'Bcheck', 'Ccheck', 'sensor1', 'sensor10', 'sensor11',
#        'sensor12', 'sensor14', 'sensor15', 'sensor18', 'sensor2', 'sensor20',
#        'sensor23', 'sensor24', 'sensor5', 'sensor6', 'sensor7', 'sensor9'],
#       dtype='object')
# Transformer: <class 'sklearn.preprocessing._data.MinMaxScaler'>
#                       Acheck        Bcheck        Ccheck       sensor1  \
# count           20631.000000  20631.000000  20631.000000  20631.000000
# mean                0.157045      0.031167      0.007368      0.499490
# std                 0.363852      0.173772      0.085520      0.125708
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.000000      0.000000      0.000000      0.413793
# 50%                 0.000000      0.000000      0.000000      0.500000
# 75%                 0.000000      0.000000      0.000000      0.586207
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.000000      0.000000      0.000000      0.500000
# coeffvariation      2.316863      5.575576     11.607618      0.251672
# nunique             2.000000      2.000000      2.000000    158.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                     sensor10      sensor11      sensor12      sensor14  \
# count           20631.000000  20631.000000  20631.000000  20631.000000
# mean                0.566459      0.297957      0.195248      0.411410
# std                 0.142527      0.107554      0.099089      0.158981
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.476651      0.227273      0.140761      0.297619
# 50%                 0.578100      0.287879      0.174684      0.392857
# 75%                 0.669887      0.363636      0.213991      0.505952
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.578100      0.287879      0.174684      0.392857
# coeffvariation      0.251610      0.360971      0.507501      0.386429
# nunique           513.000000     53.000000   6403.000000    159.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                     sensor15      sensor18       sensor2      sensor20  \
# count           20631.000000  20631.000000  20631.000000  20631.000000
# mean                0.580697      0.451118      0.501959      0.525799
# std                 0.157261      0.144306      0.244218      0.192037
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.484009      0.346287      0.333333      0.375000
# 50%                 0.594883      0.438630      0.500000      0.500000
# 75%                 0.695096      0.541362      0.750000      0.625000
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.594883      0.438630      0.500000      0.500000
# coeffvariation      0.270814      0.319884      0.486531      0.365230
# nunique           427.000000   1918.000000     13.000000      9.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                     sensor23      sensor24       sensor5       sensor6  \
# count           20631.000000  20631.000000  20631.000000  20631.000000
# mean                0.524241      0.546127      0.443052      0.424746
# std                 0.140114      0.149476      0.150618      0.133664
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.434109      0.452361      0.335843      0.331807
# 50%                 0.534884      0.557443      0.430723      0.415522
# 75%                 0.627907      0.652582      0.539157      0.508829
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.534884      0.557443      0.430723      0.415522
# coeffvariation      0.267269      0.273703      0.339956      0.314690
# nunique           120.000000   4745.000000    310.000000   3012.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                      sensor7       sensor9   unit_number  time_in_cycles  \
# count           20631.000000  20631.000000  20631.000000    20631.000000
# mean                0.450435      0.980321     51.506568      108.807862
# std                 0.151935      0.138898     29.227633       68.880990
# min                 0.000000      0.000000      1.000000        1.000000
# 25%                 0.339467      1.000000     26.000000       52.000000
# 50%                 0.435348      1.000000     52.000000      104.000000
# 75%                 0.545324      1.000000     77.000000      156.000000
# max                 1.000000      1.000000    100.000000      362.000000
# median              0.435348      1.000000     52.000000      104.000000
# coeffvariation      0.337306      0.141687      0.567454        0.633052
# nunique          4051.000000      2.000000    100.000000      362.000000
# NullCount           0.000000      0.000000      0.000000        0.000000
#
#                          RUL
# count           20631.000000
# mean              107.807862
# std                68.880990
# min                 0.000000
# 25%                51.000000
# 50%               103.000000
# 75%               155.000000
# max               361.000000
# median            103.000000
# coeffvariation      0.638924
# nunique           362.000000
# NullCount           0.000000

# %%
plt.figure()
sb.histplot(df['sensor12'])
# Out:
# <AxesSubplot:xlabel='sensor12', ylabel='Count'>

# %%
#Set up test data
test_df = pd.read_csv(data_link+test_link,sep=" ",header=None)
test_df.dropna(axis=1,inplace=True)
columns = ['unit_number','time_in_cycles','sensor1','sensor2','sensor3','sensor4','sensor5','sensor6','sensor7','sensor8','sensor9','sensor10','sensor11',
'sensor12','sensor13','sensor14','sensor15','sensor16','sensor17','sensor18','sensor19','sensor20','sensor21','sensor22','sensor23','sensor24', ]
test_df.columns = columns

# Dropping the anomalies of unit_number 10 according to findings in EDA of Sensor 9
#test_df = test_df.loc[~(test_df.unit_number==10)]

# Add 24 hour check (180) and 100 hour check (250) and week check (350 cycles)
test_df['Acheck'] = (test_df['time_in_cycles']>180).values.astype(int)
test_df['Bcheck'] = (test_df['time_in_cycles']>250).values.astype(int)
test_df['Ccheck'] = (test_df['time_in_cycles']>350).values.astype(int)

# Dropping useless columns
for a in ['sensor3','sensor4','sensor8','sensor13','sensor19','sensor21','sensor22']:
    test_df.drop(a,axis=1,inplace=True)

#drop duplicatives sensor 15,16,17
for a in ['sensor16','sensor17']:
    test_df.drop(a,axis=1,inplace=True)

#scaling
from scaling import scaling
cols_normalize = test_df.columns.difference(['unit_number','time_in_cycles'])
df_t = scaling(test_df,cols_normalize,scalers='Robust_Scaler',single=True)
df_t = scaling(df_t,cols_normalize,scalers='MinMax',single=True)

#add 'unit_number','time_in_cycles','RUL' to df_t
test_df = df_t.join(test_df[['unit_number','time_in_cycles']])

#describe function
des = test_df.describe()
des.loc['median'] = test_df.median().values
des.loc['coeffvariation'] = (test_df.std()/test_df.mean()).values
des.loc['nunique'] = test_df.nunique().values
des.loc['NullCount'] = test_df.isna().sum().values

# find the time cycle which gives the max cycles
dft = test_df
test_max = dft.groupby('unit_number')['time_in_cycles'].max().reset_index()
test_max.columns = ['unit_number','max']
dft = dft.merge(test_max, on=['unit_number'], how='left')
test = dft[dft['time_in_cycles'] == dft['max']].reset_index()
test.drop(columns=['index','max','unit_number'],inplace = True)
test_df = test.to_numpy()

RUL = pd.read_csv(data_link+rul_link,sep=" ",header=None)

print(f"Test Dataset shape: {test_df.shape}")
print(f"Train Dataset Shape: {df.shape}")
des
# Out:
# single: True
# Columns: Index(['Acheck', 'Bcheck', 'Ccheck', 'sensor1', 'sensor10', 'sensor11',
#        'sensor12', 'sensor14', 'sensor15', 'sensor18', 'sensor2', 'sensor20',
#        'sensor23', 'sensor24', 'sensor5', 'sensor6', 'sensor7', 'sensor9'],
#       dtype='object')
# Transformer: <class 'sklearn.preprocessing._data.RobustScaler'>
#
# single: True
# Columns: Index(['Acheck', 'Bcheck', 'Ccheck', 'sensor1', 'sensor10', 'sensor11',
#        'sensor12', 'sensor14', 'sensor15', 'sensor18', 'sensor2', 'sensor20',
#        'sensor23', 'sensor24', 'sensor5', 'sensor6', 'sensor7', 'sensor9'],
#       dtype='object')
# Transformer: <class 'sklearn.preprocessing._data.MinMaxScaler'>
#
# Test Dataset shape: (100, 19)
# Train Dataset Shape: (20631, 20)
#                       Acheck        Bcheck   Ccheck       sensor1  \
# count           13096.000000  13096.000000  13096.0  13096.000000
# mean                0.039401      0.004047      0.0      0.511801
# std                 0.194555      0.063490      0.0      0.137668
# min                 0.000000      0.000000      0.0      0.000000
# 25%                 0.000000      0.000000      0.0      0.418750
# 50%                 0.000000      0.000000      0.0      0.512500
# 75%                 0.000000      0.000000      0.0      0.606250
# max                 1.000000      1.000000      0.0      1.000000
# median              0.000000      0.000000      0.0      0.512500
# coeffvariation      4.937784     15.687993      NaN      0.268987
# nunique             2.000000      2.000000      1.0    150.000000
# NullCount           0.000000      0.000000      0.0      0.000000
#
#                     sensor10      sensor11      sensor12      sensor14  \
# count           13096.000000  13096.000000  13096.000000  13096.000000
# mean                0.580146      0.441377      0.259597      0.422058
# std                 0.137356      0.140102      0.087634      0.134190
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.489919      0.341463      0.202989      0.321918
# 50%                 0.588710      0.439024      0.251264      0.417808
# 75%                 0.677419      0.536585      0.303295      0.506849
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.588710      0.439024      0.251264      0.417808
# coeffvariation      0.236761      0.317420      0.337578      0.317942
# nunique           415.000000     41.000000   4047.000000    136.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                     sensor15      sensor18       sensor2      sensor20  \
# count           13096.000000  13096.000000  13096.000000  13096.000000
# mean                0.540576      0.446040      0.464798      0.446453
# std                 0.127769      0.139067      0.226177      0.154197
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.456621      0.348993      0.307692      0.375000
# 50%                 0.547945      0.441515      0.461538      0.500000
# 75%                 0.632420      0.534516      0.692308      0.500000
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.547945      0.441515      0.461538      0.500000
# coeffvariation      0.236356      0.311781      0.486614      0.345383
# nunique           357.000000   1506.000000     14.000000      9.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                     sensor23      sensor24       sensor5       sensor6  \
# count           13096.000000  13096.000000  13096.000000  13096.000000
# mean                0.529547      0.566656      0.424318      0.494916
# std                 0.128801      0.119066      0.126467      0.129921
# min                 0.000000      0.000000      0.000000      0.000000
# 25%                 0.445455      0.490021      0.336751      0.404051
# 50%                 0.536364      0.571550      0.419558      0.492080
# 75%                 0.618182      0.648549      0.507886      0.579655
# max                 1.000000      1.000000      1.000000      1.000000
# median              0.536364      0.571550      0.419558      0.492080
# coeffvariation      0.243228      0.210121      0.298047      0.262512
# nunique           103.000000   3555.000000    262.000000   2361.000000
# NullCount           0.000000      0.000000      0.000000      0.000000
#
#                      sensor7       sensor9   unit_number  time_in_cycles
# count           13096.000000  13096.000000  13096.000000    13096.000000
# mean                0.415466      0.970067     51.543907       76.836515
# std                 0.136580      0.170408     28.289423       53.057749
# min                 0.000000      0.000000      1.000000        1.000000
# 25%                 0.317746      1.000000     28.000000       33.000000
# 50%                 0.409434      1.000000     52.000000       69.000000
# 75%                 0.503574      1.000000     76.000000      113.000000
# max                 1.000000      1.000000    100.000000      303.000000
# median              0.409434      1.000000     52.000000       69.000000
# coeffvariation      0.328739      0.175667      0.548841        0.690528
# nunique          2954.000000      2.000000    100.000000      303.000000
# NullCount           0.000000      0.000000      0.000000        0.000000

# %%
# from Helper import train_models,score_func
# acc=[]
# eval_acc={}
# model_names = ['FOREST','LinR','LSVM','SVM','KNN','GNB','TREE','CAT']
# for model in model_names:
#     print(f'Algorithm: {model}')
#     model_1 = train_models(df,model)
#     y_pred = model_1.predict(test_df)

#     # Get y true
#     y_true = RUL[0].to_numpy()

#     RF_individual_scorelst = score_func(y_true, y_pred)
#     acc.append(RF_individual_scorelst)
     
# eval_acc={'Modelling Algorithm':model_names,'Accuracy':acc}
# eval_acc

# %% [markdown]
# # LSTM

# %%
from Helper import *
train_df = df
train_df_lstm = pd.concat([unit_number, train_df], axis=1)
model, history, lstm_test_df, seq_array, label_array, sequence_length, sequence_cols = train_models([train_df_lstm, dft, RUL.copy()], "LSTM",epoch=230)
lstm_test_evaluation_graphs(model, history, seq_array, label_array)
# Out:
# train_df:-     unit_number  Acheck  Bcheck  Ccheck   sensor1  sensor10  sensor11  \
# 0            1     0.0     0.0     0.0  0.459770  0.726248  0.242424
# 1            1     0.0     0.0     0.0  0.609195  0.628019  0.212121
#
#    sensor12  sensor14  sensor15  sensor18   sensor2  sensor20  sensor23  \
# 0  0.109755  0.369048  0.633262  0.363986  0.166667     0.375  0.713178
# 1  0.100242  0.380952  0.765458  0.411312  0.250000     0.375  0.666667
#
#    sensor24   sensor5   sensor6   sensor7  sensor9  time_in_cycles  RUL  \
# 0  0.724662  0.183735  0.406802  0.309757      1.0               1  191
# 1  0.731014  0.283133  0.453019  0.352633      1.0               2  190
#
#    label1  label2  cycle_norm
# 0       0       0     0.00000
# 1       0       0     0.00277
#
#
# test_df:-     Acheck  Bcheck  Ccheck  sensor1  sensor10  sensor11  sensor12  sensor14  \
# 0     0.0     0.0     0.0  0.65625  0.608871  0.365854  0.196475  0.273973
# 1     0.0     0.0     0.0  0.34375  0.800403  0.292683  0.229042  0.479452
#
#    sensor15  sensor18   sensor2  sensor20  sensor23  sensor24   sensor5  \
# 0  0.534247  0.347076  0.692308     0.375  0.500000  0.620099  0.596215
# 1  0.634703  0.227709  0.230769     0.500  0.645455  0.645718  0.182965
#
#     sensor6   sensor7  sensor9  unit_number  time_in_cycles  cycle_norm  RUL  \
# 0  0.421968  0.282214      1.0            1               1    0.000000  142
# 1  0.504025  0.225240      1.0            1               2    0.003311  141
#
#    label1  label2
# 0       0       0
# 1       0       0
# Validation List Length: 142
# Train Sequence Array Shape: (15631, 50, 21)
# Label Array Shape: (15631, 1)
# Label Array: [[141.]
#  [140.]
#  [139.]
#  ...
#  [  2.]
#  [  1.]
#  [  0.]]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 50, 15)            2220
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50, 15)            1860
# _________________________________________________________________
# dropout (Dropout)            (None, 50, 15)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50, 15)            1860
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50, 15)            0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 15)                1860
# _________________________________________________________________
# dense (Dense)                (None, 1)                 16
# _________________________________________________________________
# activation (Activation)      (None, 1)                 0
# =================================================================
# Total params: 7,816
# Trainable params: 7,816
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 14849 samples, validate on 782 samples
# Epoch 1/230
# 14849/14849 - 11s - loss: 10145.6960 - mae: 82.9461 - r2_keras: -2.1160e+00 - val_loss: 9663.2895 - val_mae: 80.6926 - val_r2_keras: -2.7403e+00
# Epoch 2/230
# 14849/14849 - 2s - loss: 9676.5137 - mae: 80.1917 - r2_keras: -1.9771e+00 - val_loss: 9366.7124 - val_mae: 78.9465 - val_r2_keras: -2.6045e+00
# Epoch 3/230
# 14849/14849 - 1s - loss: 9456.7836 - mae: 78.9091 - r2_keras: -1.9096e+00 - val_loss: 9197.9679 - val_mae: 77.9549 - val_r2_keras: -2.5276e+00
# Epoch 4/230
# 14849/14849 - 1s - loss: 9302.8179 - mae: 78.0138 - r2_keras: -1.8655e+00 - val_loss: 9057.1971 - val_mae: 77.1283 - val_r2_keras: -2.4635e+00
# Epoch 5/230
# 14849/14849 - 1s - loss: 9166.4759 - mae: 77.2163 - r2_keras: -1.8174e+00 - val_loss: 8926.5053 - val_mae: 76.3613 - val_r2_keras: -2.4042e+00
# Epoch 6/230
# Epoch 127/230
# 14849/14849 - 1s - loss: 3335.8375 - mae: 45.9120 - r2_keras: -2.3429e-02 - val_loss: 3223.6452 - val_mae: 45.4264 - val_r2_keras: -2.5897e-01
# Epoch 128/230
# 14849/14849 - 1s - loss: 3330.7921 - mae: 45.9085 - r2_keras: -2.0952e-02 - val_loss: 3218.9322 - val_mae: 45.4214 - val_r2_keras: -2.6099e-01
# Epoch 129/230
# 14849/14849 - 2s - loss: 3326.0132 - mae: 45.9042 - r2_keras: -1.9908e-02 - val_loss: 3214.6508 - val_mae: 45.4190 - val_r2_keras: -2.6302e-01
# Epoch 130/230
# 14849/14849 - 2s - loss: 3321.5554 - mae: 45.9032 - r2_keras: -1.9513e-02 - val_loss: 3210.6983 - val_mae: 45.4182 - val_r2_keras: -2.6507e-01
# Epoch 131/230
# 14849/14849 - 2s - loss: 3317.3681 - mae: 45.9027 - r2_keras: -1.6547e-02 - val_loss: 3206.9236 - val_mae: 45.4175 - val_r2_keras: -2.6722e-01
# Epoch 132/230
# 14849/14849 - 2s - loss: 3313.4708 - mae: 45.9023 - r2_keras: -1.5659e-02 - val_loss: 3203.2850 - val_mae: 45.4176 - val_r2_keras: -2.6948e-01
# Epoch 133/230
# 14849/14849 - 2s - loss: 3309.7519 - mae: 45.9031 - r2_keras: -1.5038e-02 - val_loss: 3200.0851 - val_mae: 45.4204 - val_r2_keras: -2.7166e-01
# Epoch 134/230
# 14849/14849 - 2s - loss: 3306.3860 - mae: 45.9088 - r2_keras: -1.4562e-02 - val_loss: 3196.8839 - val_mae: 45.4233 - val_r2_keras: -2.7404e-01
# Epoch 135/230
# 14849/14849 - 2s - loss: 3303.1729 - mae: 45.9095 - r2_keras: -1.3436e-02 - val_loss: 3194.2389 - val_mae: 45.4259 - val_r2_keras: -2.7618e-01
# Epoch 136/230
# 14849/14849 - 2s - loss: 3300.2666 - mae: 45.9129 - r2_keras: -1.3345e-02 - val_loss: 3191.6136 - val_mae: 45.4304 - val_r2_keras: -2.7848e-01
# Epoch 137/230
# 14849/14849 - 2s - loss: 3297.5170 - mae: 45.9194 - r2_keras: -1.1146e-02 - val_loss: 3189.2094 - val_mae: 45.4363 - val_r2_keras: -2.8078e-01
# Epoch 138/230
# 14849/14849 - 2s - loss: 3294.9765 - mae: 45.9244 - r2_keras: -1.0447e-02 - val_loss: 3187.0323 - val_mae: 45.4418 - val_r2_keras: -2.8304e-01
# Epoch 139/230
# 14849/14849 - 2s - loss: 3292.6486 - mae: 45.9310 - r2_keras: -9.1672e-03 - val_loss: 3184.9362 - val_mae: 45.4475 - val_r2_keras: -2.8541e-01
# Epoch 140/230
# 14849/14849 - 2s - loss: 3290.4363 - mae: 45.9361 - r2_keras: -1.0058e-02 - val_loss: 3183.1742 - val_mae: 45.4539 - val_r2_keras: -2.8757e-01
# Epoch 141/230
# 14849/14849 - 2s - loss: 3288.4775 - mae: 45.9448 - r2_keras: -8.8788e-03 - val_loss: 3181.3331 - val_mae: 45.4626 - val_r2_keras: -2.9003e-01
# Epoch 157/230
# 14849/14849 - 1s - loss: 3272.7210 - mae: 46.0772 - r2_keras: -3.7279e-03 - val_loss: 3168.9288 - val_mae: 45.5949 - val_r2_keras: -3.2087e-01
# Epoch 158/230
# 14849/14849 - 2s - loss: 3272.3834 - mae: 46.0844 - r2_keras: -4.0275e-03 - val_loss: 3168.6996 - val_mae: 45.6034 - val_r2_keras: -3.2242e-01
# Epoch 159/230
# 14849/14849 - 2s - loss: 3272.0980 - mae: 46.0940 - r2_keras: -4.3712e-03 - val_loss: 3168.5116 - val_mae: 45.6115 - val_r2_keras: -3.2387e-01
# Epoch 160/230
# 14849/14849 - 2s - loss: 3271.8414 - mae: 46.1024 - r2_keras: -3.3076e-03 - val_loss: 3168.3528 - val_mae: 45.6193 - val_r2_keras: -3.2529e-01
# Epoch 161/230
# 14849/14849 - 2s - loss: 3271.6126 - mae: 46.1080 - r2_keras: -3.6743e-03 - val_loss: 3168.2469 - val_mae: 45.6252 - val_r2_keras: -3.2638e-01
# Epoch 162/230
# 14849/14849 - 2s - loss: 3271.4376 - mae: 46.1164 - r2_keras: -3.3208e-03 - val_loss: 3168.1399 - val_mae: 45.6321 - val_r2_keras: -3.2764e-01
# Epoch 163/230
# 14849/14849 - 2s - loss: 3271.2475 - mae: 46.1205 - r2_keras: -4.4980e-03 - val_loss: 3168.0703 - val_mae: 45.6373 - val_r2_keras: -3.2861e-01
# Epoch 164/230
# 14849/14849 - 2s - loss: 3271.1089 - mae: 46.1264 - r2_keras: -3.6352e-03 - val_loss: 3167.9993 - val_mae: 45.6436 - val_r2_keras: -3.2978e-01
# Epoch 165/230
# 14849/14849 - 2s - loss: 3270.9990 - mae: 46.1354 - r2_keras: -4.0014e-03 - val_loss: 3167.9317 - val_mae: 45.6514 - val_r2_keras: -3.3125e-01
# Epoch 166/230
# 14849/14849 - 2s - loss: 3270.8759 - mae: 46.1370 - r2_keras: -3.6325e-03 - val_loss: 3167.9186 - val_mae: 45.6533 - val_r2_keras: -3.3160e-01
# Epoch 167/230
# 14849/14849 - 2s - loss: 3270.8070 - mae: 46.1447 - r2_keras: -4.7833e-03 - val_loss: 3167.8830 - val_mae: 45.6599 - val_r2_keras: -3.3285e-01
# Epoch 168/230
# 14849/14849 - 2s - loss: 3270.7071 - mae: 46.1465 - r2_keras: -2.4036e-03 - val_loss: 3167.8704 - val_mae: 45.6635 - val_r2_keras: -3.3353e-01
# Epoch 169/230
# 14849/14849 - 2s - loss: 3270.6379 - mae: 46.1500 - r2_keras: -2.8437e-03 - val_loss: 3167.8643 - val_mae: 45.6662 - val_r2_keras: -3.3404e-01
# Epoch 170/230
# 14849/14849 - 2s - loss: 3270.5783 - mae: 46.1551 - r2_keras: -4.6720e-03 - val_loss: 3167.8593 - val_mae: 45.6720 - val_r2_keras: -3.3511e-01
# Epoch 171/230
# 14849/14849 - 2s - loss: 3270.5367 - mae: 46.1600 - r2_keras: -2.3227e-03 - val_loss: 3167.8610 - val_mae: 45.6756 - val_r2_keras: -3.3571e-01
# Epoch 172/230
# 14849/14849 - 2s - loss: 3270.5023 - mae: 46.1633 - r2_keras: -2.1948e-03 - val_loss: 3167.8642 - val_mae: 45.6780 - val_r2_keras: -3.3609e-01
# Epoch 173/230
# 14849/14849 - 2s - loss: 3270.4727 - mae: 46.1645 - r2_keras: -2.6785e-03 - val_loss: 3167.8704 - val_mae: 45.6810 - val_r2_keras: -3.3659e-01
# Epoch 174/230
# 14849/14849 - 1s - loss: 3270.4511 - mae: 46.1702 - r2_keras: -3.3819e-03 - val_loss: 3167.8862 - val_mae: 45.6861 - val_r2_keras: -3.3743e-01
# Epoch 175/230
# 14849/14849 - 2s - loss: 3270.4210 - mae: 46.1744 - r2_keras: -1.9838e-03 - val_loss: 3167.8996 - val_mae: 45.6891 - val_r2_keras: -3.3794e-01
# Epoch 176/230
# 14849/14849 - 2s - loss: 3270.4079 - mae: 46.1766 - r2_keras: -3.8165e-03 - val_loss: 3167.9132 - val_mae: 45.6919 - val_r2_keras: -3.3841e-01
# Epoch 177/230
# 14849/14849 - 2s - loss: 3270.4012 - mae: 46.1768 - r2_keras: -2.6450e-03 - val_loss: 3167.9152 - val_mae: 45.6922 - val_r2_keras: -3.3846e-01
# Epoch 178/230
# 14849/14849 - 2s - loss: 3270.3937 - mae: 46.1812 - r2_keras: -3.4632e-03 - val_loss: 3167.9379 - val_mae: 45.6961 - val_r2_keras: -3.3910e-01
# Epoch 179/230
# 14849/14849 - 2s - loss: 3270.3806 - mae: 46.1807 - r2_keras: -2.3600e-03 - val_loss: 3167.9375 - val_mae: 45.6960 - val_r2_keras: -3.3909e-01
# Epoch 180/230
# 14849/14849 - 2s - loss: 3270.3637 - mae: 46.1837 - r2_keras: -3.3221e-03 - val_loss: 3167.9613 - val_mae: 45.6994 - val_r2_keras: -3.3967e-01
# Epoch 181/230
# 14849/14849 - 2s - loss: 3270.3702 - mae: 46.1871 - r2_keras: -4.1424e-03 - val_loss: 3167.9745 - val_mae: 45.7012 - val_r2_keras: -3.3997e-01
# Epoch 182/230
# 14849/14849 - 2s - loss: 3270.3717 - mae: 46.1869 - r2_keras: -3.6408e-03 - val_loss: 3167.9770 - val_mae: 45.7015 - val_r2_keras: -3.4002e-01
# Epoch 183/230
# 14849/14849 - 2s - loss: 3270.3712 - mae: 46.1866 - r2_keras: -3.6121e-03 - val_loss: 3167.9824 - val_mae: 45.7022 - val_r2_keras: -3.4013e-01
# Epoch 184/230
# 14849/14849 - 2s - loss: 3270.3598 - mae: 46.1905 - r2_keras: -1.9766e-03 - val_loss: 3167.9990 - val_mae: 45.7042 - val_r2_keras: -3.4047e-01
# Epoch 185/230
# 14849/14849 - 2s - loss: 3270.3524 - mae: 46.1891 - r2_keras: -3.2251e-03 - val_loss: 3167.9983 - val_mae: 45.7041 - val_r2_keras: -3.4046e-01
# Epoch 186/230
# 14849/14849 - 2s - loss: 3270.3736 - mae: 46.1940 - r2_keras: -3.3775e-03 - val_loss: 3168.0235 - val_mae: 45.7073 - val_r2_keras: -3.4099e-01
# Epoch 187/230
# 14849/14849 - 2s - loss: 2799.7586 - mae: 40.3386 - r2_keras: 0.1424 - val_loss: 2941.0248 - val_mae: 43.0619 - val_r2_keras: -3.0627e-01
# Epoch 188/230
# 14849/14849 - 2s - loss: 2587.3287 - mae: 37.9054 - r2_keras: 0.2079 - val_loss: 3263.8749 - val_mae: 46.6418 - val_r2_keras: -3.5963e-01
# Epoch 189/230
# 14849/14849 - 2s - loss: 2486.4612 - mae: 36.8127 - r2_keras: 0.2379 - val_loss: 3079.0349 - val_mae: 44.1693 - val_r2_keras: -1.6106e-01
# Epoch 190/230
# 14849/14849 - 2s - loss: 2490.7647 - mae: 37.2699 - r2_keras: 0.2379 - val_loss: 2989.7012 - val_mae: 44.3157 - val_r2_keras: -1.8507e-01
# Epoch 191/230
# 14849/14849 - 2s - loss: 2385.1570 - mae: 36.0030 - r2_keras: 0.2697 - val_loss: 3122.7775 - val_mae: 46.0794 - val_r2_keras: -3.5765e-01
# Epoch 192/230
# 14849/14849 - 1s - loss: 2295.0392 - mae: 35.0920 - r2_keras: 0.2985 - val_loss: 2871.4915 - val_mae: 43.7476 - val_r2_keras: -2.2595e-01
# Epoch 193/230
# 14849/14849 - 1s - loss: 2147.1515 - mae: 32.9489 - r2_keras: 0.3426 - val_loss: 2705.8052 - val_mae: 41.7375 - val_r2_keras: -2.4908e-01
# Epoch 194/230
# 14849/14849 - 1s - loss: 1990.2568 - mae: 31.2565 - r2_keras: 0.3921 - val_loss: 1939.7952 - val_mae: 32.6284 - val_r2_keras: 0.2789
# Epoch 195/230
# 14849/14849 - 1s - loss: 1806.5633 - mae: 28.5563 - r2_keras: 0.4479 - val_loss: 1731.9011 - val_mae: 29.0219 - val_r2_keras: 0.3974
# Epoch 196/230
# 14849/14849 - 1s - loss: 1675.5293 - mae: 26.2392 - r2_keras: 0.4893 - val_loss: 1642.1165 - val_mae: 27.2010 - val_r2_keras: 0.4438
# Epoch 197/230
# 14849/14849 - 1s - loss: 1620.9382 - mae: 25.5498 - r2_keras: 0.5074 - val_loss: 1567.5841 - val_mae: 26.4549 - val_r2_keras: 0.4830
# Epoch 198/230
# 14849/14849 - 1s - loss: 1566.4257 - mae: 24.7374 - r2_keras: 0.5214 - val_loss: 1575.8234 - val_mae: 26.9690 - val_r2_keras: 0.4674
# Epoch 199/230
# 14849/14849 - 1s - loss: 1524.8862 - mae: 24.1539 - r2_keras: 0.5345 - val_loss: 1512.2969 - val_mae: 25.2887 - val_r2_keras: 0.5094
# Epoch 200/230
# 14849/14849 - 1s - loss: 1490.7055 - mae: 23.8534 - r2_keras: 0.5444 - val_loss: 1535.1065 - val_mae: 26.6662 - val_r2_keras: 0.4646
# Epoch 201/230
# 14849/14849 - 1s - loss: 1445.6885 - mae: 23.0881 - r2_keras: 0.5603 - val_loss: 1368.1121 - val_mae: 22.9119 - val_r2_keras: 0.5760
# Epoch 202/230
# 14849/14849 - 1s - loss: 1412.8125 - mae: 22.7212 - r2_keras: 0.5690 - val_loss: 1353.9272 - val_mae: 22.5653 - val_r2_keras: 0.5980
# Epoch 203/230
# 14849/14849 - 1s - loss: 1381.0751 - mae: 22.3615 - r2_keras: 0.5783 - val_loss: 1420.7431 - val_mae: 25.3020 - val_r2_keras: 0.5136
# Epoch 204/230
# 14849/14849 - 2s - loss: 1351.6697 - mae: 22.0474 - r2_keras: 0.5872 - val_loss: 1319.9727 - val_mae: 22.9555 - val_r2_keras: 0.5984
# Epoch 205/230
# 14849/14849 - 2s - loss: 1315.0630 - mae: 21.4857 - r2_keras: 0.5989 - val_loss: 1317.1358 - val_mae: 22.9385 - val_r2_keras: 0.5827
# Epoch 206/230
# 14849/14849 - 2s - loss: 1291.7199 - mae: 21.2688 - r2_keras: 0.6075 - val_loss: 1284.9532 - val_mae: 22.1850 - val_r2_keras: 0.6012
# Epoch 207/230
# 14849/14849 - 2s - loss: 1268.1010 - mae: 20.9717 - r2_keras: 0.6129 - val_loss: 1248.9170 - val_mae: 21.5181 - val_r2_keras: 0.6225
# Epoch 208/230
# 14849/14849 - 1s - loss: 1249.7973 - mae: 20.8688 - r2_keras: 0.6188 - val_loss: 1235.9956 - val_mae: 21.5447 - val_r2_keras: 0.6243
# Epoch 209/230
# 14849/14849 - 2s - loss: 1221.8186 - mae: 20.4921 - r2_keras: 0.6286 - val_loss: 1219.9236 - val_mae: 21.2358 - val_r2_keras: 0.6309
# Epoch 210/230
# 14849/14849 - 2s - loss: 1202.1372 - mae: 20.2876 - r2_keras: 0.6341 - val_loss: 1170.2653 - val_mae: 20.9555 - val_r2_keras: 0.6388
# Epoch 211/230
# 14849/14849 - 2s - loss: 1187.5958 - mae: 20.2293 - r2_keras: 0.6378 - val_loss: 1195.8845 - val_mae: 21.3302 - val_r2_keras: 0.6237
# Epoch 212/230
# 14849/14849 - 1s - loss: 1170.8529 - mae: 20.0985 - r2_keras: 0.6434 - val_loss: 1125.2808 - val_mae: 20.2332 - val_r2_keras: 0.6502
# Epoch 213/230
# 14849/14849 - 2s - loss: 1149.8128 - mae: 19.8441 - r2_keras: 0.6497 - val_loss: 1126.4896 - val_mae: 20.2619 - val_r2_keras: 0.6498
# Epoch 214/230
# 14849/14849 - 2s - loss: 1134.3440 - mae: 19.6728 - r2_keras: 0.6543 - val_loss: 1152.4272 - val_mae: 20.5553 - val_r2_keras: 0.6521
# Epoch 215/230
# 14849/14849 - 2s - loss: 1115.4957 - mae: 19.4696 - r2_keras: 0.6594 - val_loss: 1105.6341 - val_mae: 20.6259 - val_r2_keras: 0.6415
# Epoch 216/230
# 14849/14849 - 2s - loss: 1105.5942 - mae: 19.4899 - r2_keras: 0.6625 - val_loss: 1108.9086 - val_mae: 20.1675 - val_r2_keras: 0.6461
# Epoch 217/230
# 14849/14849 - 1s - loss: 1080.8865 - mae: 19.0430 - r2_keras: 0.6708 - val_loss: 1070.5225 - val_mae: 19.8298 - val_r2_keras: 0.6613
# Epoch 218/230
# 14849/14849 - 2s - loss: 1077.5107 - mae: 19.2292 - r2_keras: 0.6716 - val_loss: 1075.0191 - val_mae: 19.5410 - val_r2_keras: 0.6584
# Epoch 219/230
# 14849/14849 - 1s - loss: 1058.8480 - mae: 18.9455 - r2_keras: 0.6764 - val_loss: 1072.5539 - val_mae: 20.1478 - val_r2_keras: 0.6419
# Epoch 220/230
# 14849/14849 - 2s - loss: 1051.0092 - mae: 19.0393 - r2_keras: 0.6788 - val_loss: 1061.6811 - val_mae: 19.6261 - val_r2_keras: 0.6614
# Epoch 221/230
# 14849/14849 - 2s - loss: 1037.2196 - mae: 18.8168 - r2_keras: 0.6826 - val_loss: 1012.5230 - val_mae: 19.1307 - val_r2_keras: 0.6685
# Epoch 222/230
# 14849/14849 - 2s - loss: 1028.2942 - mae: 18.7920 - r2_keras: 0.6865 - val_loss: 1037.3263 - val_mae: 19.1033 - val_r2_keras: 0.6683
# Epoch 223/230
# 14849/14849 - 2s - loss: 1014.0745 - mae: 18.6501 - r2_keras: 0.6917 - val_loss: 1004.7770 - val_mae: 19.3489 - val_r2_keras: 0.6609
# Epoch 224/230
# 14849/14849 - 2s - loss: 1001.3744 - mae: 18.5125 - r2_keras: 0.6955 - val_loss: 1034.3621 - val_mae: 18.6924 - val_r2_keras: 0.6843
# Epoch 225/230
# 14849/14849 - 1s - loss: 982.5805 - mae: 18.2228 - r2_keras: 0.7004 - val_loss: 996.9232 - val_mae: 18.7912 - val_r2_keras: 0.6731
# Epoch 226/230
# 14849/14849 - 1s - loss: 979.1264 - mae: 18.4075 - r2_keras: 0.7007 - val_loss: 990.1516 - val_mae: 18.8831 - val_r2_keras: 0.6741
# Epoch 227/230
# 14849/14849 - 1s - loss: 966.3771 - mae: 18.1399 - r2_keras: 0.7065 - val_loss: 993.3531 - val_mae: 19.5669 - val_r2_keras: 0.6819
# Epoch 228/230
# 14849/14849 - 1s - loss: 951.0296 - mae: 17.9674 - r2_keras: 0.7102 - val_loss: 973.8175 - val_mae: 18.7785 - val_r2_keras: 0.6659
# Epoch 229/230
# 14849/14849 - 1s - loss: 934.0494 - mae: 17.6949 - r2_keras: 0.7158 - val_loss: 961.1537 - val_mae: 18.6177 - val_r2_keras: 0.6743
# Epoch 230/230
# 14849/14849 - 1s - loss: 925.1461 - mae: 17.6226 - r2_keras: 0.7183 - val_loss: 943.7781 - val_mae: 18.2189 - val_r2_keras: 0.6804
# History Keys: dict_keys(['loss', 'mae', 'r2_keras', 'val_loss', 'val_mae', 'val_r2_keras'])
#
# MAE: 17.070053100585938
#
# R^2: 0.7409214377403259

# %%
MAE, R2, y_pred = lstm_valid_evaluation(lstm_test_df, model, sequence_length, sequence_cols)
# mae, rmse, r2
LSTM_individual_scorelst = [round(MAE,2), 0, round(R2,2)*100]
# Out:
# Test Sequence Array Shape: (93, 50, 21)
# Test Label Array Shape: (93, 1)
#
# MAE: 22.43999481201172
#
# R^2: 0.513724684715271
# Pred set: (93, 1)

# %%
# logger.info('-------------- Save Model ---------------') 
# model.save('model/model1.h5')
